# %%
# 학번과 이름을 출력하세요
# 예시
# 학번 = '20252422'
# 이름 = '박연우'

학번 = '20252422'
이름 = '박연우'

print(학번, 이름)
# Out:
# 20252422 박연우

# %%
def factorial(n):
    """returns n!"""
    return 1 if n < 2 else n * factorial(n-1)
factorial(42)
# Out:
# 1405006117752879898543142606244511569936384000000000

# %%
factorial.__doc__
# Out:
# 'returns n!'

# %%
type(factorial)
# Out:
# function

# %%
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(n)
#     returns n!

# %%
fact = factorial
fact
# Out:
# <function __main__.factorial(n)>

# %%
fact(5)
# Out:
# 120

# %%
map (factorial, range(11))

# %%
list (map(fact, range(11)))
# Out:
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspbrry', 'banana']
sorted(fruits, key=len)
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspbrry', 'strawberry']

# %%
def reverse(word):
    return word[::-1]
reverse('testing')
# Out:
# 'gnitset'

# %%
sorted(fruits, key=reverse)
# Out:
# ['banana', 'apple', 'fig', 'raspbrry', 'strawberry', 'cherry']

# %%
list(map(fact, range(6)))
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
[fact(n) for n in range(6)]
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
list(map(factorial, filter(lambda n: n % 2, range(6))))
# Out:
# [1, 6, 120]

# %%
[factorial(n) for n in range(6) if n %2]
# Out:
# [1, 6, 120]

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspbrry', 'banana']
sorted(fruits, key=lambda word: word[::-1])
# Out:
# ['banana', 'apple', 'fig', 'raspbrry', 'strawberry', 'cherry']

# %%
abs, str, 13
# Out:
# (<function abs(x, /)>, str, 13)

# %%
[callable(obj) for obj in (abs, str, 13)]
# Out:
# [True, True, False]

# %%
import random

class BingoCage:

    def __init__(self, items):
        self._items = list(items)
        random.shuffle(self._items)

    def pick(self):
        try:
            return self._items.pop()
        except:
            raise LookupError('pick from empty BingoCage')

    def __call__(self):
        return self.pick()

# %%
bingo = BingoCage(range(3))
bingo.pick()
# Out:
# 0

# %%
bingo()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 11, in BingoCage.pick(self)
#      10 try:
# ---> 11     return self._items.pop()
#      12 except:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 bingo()
#
# Cell In[34], line 16, in BingoCage.__call__(self)
#      15 def __call__(self):
# ---> 16     return self.pick()
#
# Cell In[34], line 13, in BingoCage.pick(self)
#      11     return self._items.pop()
#      12 except:
# ---> 13     raise LookupError('pick from empty BingoCage')
#
# LookupError: pick from empty BingoCage

# %%
callable(bingo)
# Out:
# True

# %%
bingo()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 11, in BingoCage.pick(self)
#      10 try:
# ---> 11     return self._items.pop()
#      12 except:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 bingo()
#
# Cell In[34], line 16, in BingoCage.__call__(self)
#      15 def __call__(self):
# ---> 16     return self.pick()
#
# Cell In[34], line 13, in BingoCage.pick(self)
#      11     return self._items.pop()
#      12 except:
# ---> 13     raise LookupError('pick from empty BingoCage')
#
# LookupError: pick from empty BingoCage

# %%
def tag(name, *content, cls=None, **attrs):
    if cls is not None:
        attrs['class'] = cls

    if attrs:
        attr_str = ''.join(' %s="%s"' % (attr, value)
                           for attr, value in sorted(attrs.items()))
    else:
        attr_str = ''

    if content:
        return '\n'.join('<%s%s>%s</%s>' %
                         (name, attr_str, c, name) for c in content)
    else:
        return '<%s%s />' % (name, attr_str)

# %%
tag('br')
# Out:
# '<br />'

# %%
tag('p', 'hello')
# Out:
# '<p>hello</p>'

# %%
print(tag('p', 'hello', 'world',))
# Out:
# <p>hello</p>
# <p>world</p>

# %%
tag('p', 'hello', id=33)
# Out:
# '<p id="33">hello</p>'

# %%
print(tag('p', 'hello', 'world', cls='sidebar'))
# Out:
# <p class="sidebar">hello</p>
# <p class="sidebar">world</p>

# %%
tag(content='testing', name='img')
# Out:
# '<img content="testing" />'

# %%
my_tag = {'name': 'img', 'title': 'Sunset Boulevard',
          'src': 'sunset.jpg', 'cls': 'framed'}
tag(**my_tag)
# Out:
# '<img class="framed" src="sunset.jpg" title="Sunset Boulevard" />'

# %%
def f(a, *, b):
    return a, b

f(1, b=2)
# Out:
# (1, 2)

# %%
def create_user(name, *, age, is_admin=False):
    print(f"Name: {name}, Age: {age}, Admin: {is_admin}")

create_user("Alice", age=30, is_admin=True)

create_user("Bob", 25)
# Out:
# Name: Alice, Age: 30, Admin: True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 6
#       2     print(f"Name: {name}, Age: {age}, Admin: {is_admin}")
#       4 create_user("Alice", age=30, is_admin=True)
# ----> 6 create_user("Bob", 25)
#
# TypeError: create_user() takes 1 positional argument but 2 were given

# %%
def clip(text, max_len=80):
    """max_len 문자에 가까운 마지막 공백에서 잘라낸 문자열을 반환한다."""

    end = None

    if len(text) > max_len:
        space_before = text.rfind(' ', 0, max_len)

        if space_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_len)

            if space_after >= 0:
                end = space_after

    if end is None:
        end = len(text)

    return text[:end].rstrip()

# %%
clip.__defaults__
# Out:
# (80,)

# %%
clip.__code__
# Out:
# <code object clip at 0x0000024529334920, file "C:\Users\user\AppData\Local\Temp\ipykernel_9788\536692739.py", line 1>

# %%
clip.__code__.co_varnames
# Out:
# ('text', 'max_len', 'end', 'space_before', 'space_after')

# %%
clip.__code__.co_argcount
# Out:
# 2

# %%
from inspect import signature

sig = signature(clip)
sig
# Out:
# <Signature (text, max_len=80)>

# %%
str(sig)
# Out:
# '(text, max_len=80)'

# %%
for name, param in sig.parameters.items():
    print(param.kind, ":", name, "=", param.default)
# Out:
# POSITIONAL_OR_KEYWORD : text = <class 'inspect._empty'>
# POSITIONAL_OR_KEYWORD : max_len = 80

# %%
from inspect import signature

sig = signature(tag)
my_tag
# Out:
# {'name': 'img',
#  'title': 'Sunset Boulevard',
#  'src': 'sunset.jpg',
#  'cls': 'framed'}

# %%
bound_args = sig.bind(**my_tag)

bound_args
# Out:
# <BoundArguments (name='img', cls='framed', attrs={'title': 'Sunset Boulevard', 'src': 'sunset.jpg'})>

# %%
for name, value in bound_args.arguments.items():
    print(name, '=', value)
# Out:
# name = img
# cls = framed
# attrs = {'title': 'Sunset Boulevard', 'src': 'sunset.jpg'}

# %%
del my_tag['name']

bound_args = sig.bind(**my_tag)

bound_args
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 3
#       1 del my_tag['name']
# ----> 3 bound_args = sig.bind(**my_tag)
#       5 bound_args
#
# File c:\Users\user\.conda\envs\20261830_env\lib\inspect.py:3186, in Signature.bind(self, *args, **kwargs)
#    3181 def bind(self, /, *args, **kwargs):
#    3182     """Get a BoundArguments object, that maps the passed `args`
#    3183     and `kwargs` to the function's signature.  Raises `TypeError`
#    3184     if the passed arguments can not be bound.
#    3185     """
# -> 3186     return self._bind(args, kwargs)
#
# File c:\Users\user\.conda\envs\20261830_env\lib\inspect.py:3101, in Signature._bind(self, args, kwargs, partial)
#    3099                 msg = 'missing a required argument: {arg!r}'
#    3100                 msg = msg.format(arg=param.name)
# -> 3101                 raise TypeError(msg) from None
#    3102 else:
#    3103     # We have a positional argument to process
#    3104     try:
#
# TypeError: missing a required argument: 'name'

# %%
def clip_fa(text: str, max_len: 'int > 0' = 80) -> str:
    """max_len 문자에 가까운 마지막 공백에서 잘라낸 문자열을 반환한다."""

    end = None

    if len(text) > max_len:
        space_before = text.rfind(' ', 0, max_len)

        if space_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_len)

            if space_after >= 0:
                end = space_after

    if end is None:
        end = len(text)

    return text[:end].rstrip()

# %%
clip_fa.__annotations__
# Out:
# {'text': str, 'max_len': 'int > 0', 'return': str}

# %%
sig2 = signature(clip_fa)

sig2.return_annotation
# Out:
# str

# %%
for param in sig2.parameters.values():
    note = repr(param.annotation).ljust(13)
    print(note, ':', param.name, '=', param.default)
# Out:
# <class 'str'> : text = <class 'inspect._empty'>
# 'int > 0'     : max_len = 80

# %%
from functools import reduce

def fact(n):
    return reduce(lambda a, b: a * b, range(1, n+1))

fact(10)
# Out:
# 3628800

# %%
from operator import mul

def fact(n):
    return reduce(mul, range(1, n+1))

mul(1, 2)
mul(2, 3)
mul(6, 4)

fact(10)

mul(24, 5)

mul(362880, 10)
# Out:
# 3628800

# %%
metro_data = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
    ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
    ('Sao Paulo', 'BR', 19.649, (-23.547778, -46.635833)),
]

from operator import itemgetter

for city in sorted(metro_data, key=itemgetter(1)):
    print(city)
# Out:
# ('Sao Paulo', 'BR', 19.649, (-23.547778, -46.635833))
# ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889))
# ('Tokyo', 'JP', 36.933, (35.689722, 139.691667))
# ('Mexico City', 'MX', 20.142, (19.433333, -99.133333))
# ('New York-Newark', 'US', 20.104, (40.808611, -74.020386))

# %%
cc_name = itemgetter(1, 0)

for city in metro_data:
    print(cc_name(city))
# Out:
# ('JP', 'Tokyo')
# ('IN', 'Delhi NCR')
# ('MX', 'Mexico City')
# ('US', 'New York-Newark')
# ('BR', 'Sao Paulo')

# %%
from collections import namedtuple

LatLong = namedtuple('LatLong', 'lat long')
Metropolis = namedtuple('Metropolis', 'name cc pop coord')

metro_areas = [
    Metropolis(name, cc, pop, LatLong(lat, long))
    for name, cc, pop, (lat, long) in metro_data
]

metro_areas[0]

metro_areas[0].coord.lat

from operator import attrgetter

name_lat = attrgetter('name', 'coord.lat')

name_lat(metro_areas[0])
# Out:
# ('Tokyo', 35.689722)

# %%
for city in sorted(metro_areas, key=attrgetter('coord.lat')):
    print(name_lat(city))
# Out:
# ('Sao Paulo', -23.547778)
# ('Mexico City', 19.433333)
# ('Delhi NCR', 28.613889)
# ('Tokyo', 35.689722)
# ('New York-Newark', 40.808611)

# %%
metro_areas2 = [Metropolis(name, cc, pop, LatLong(*loc))
                for name, cc, pop, loc in metro_data
]

metro_areas2[0]
# Out:
# Metropolis(name='Tokyo', cc='JP', pop=36.933, coord=LatLong(lat=35.689722, long=139.691667))

# %%
from operator import methodcaller

s = 'The time has come'

upcase = methodcaller('upper')

upcase(s)
# Out:
# 'THE TIME HAS COME'

# %%
s.upper()
# Out:
# 'THE TIME HAS COME'

# %%
hiphenate = methodcaller('replace', ' ', '-')

hiphenate(s)
# Out:
# 'The-time-has-come'

# %%
from operator import mul
from functools import partial

triple = partial(mul, 3)

triple(7)
# Out:
# 21

# %%
list(map(triple, range(1, 10)))
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
tag

picture = partial(tag, 'img', cls='pic-frame')

picture(src='wumpus.jpg')
# Out:
# '<img class="pic-frame" src="wumpus.jpg" />'

# %%
tag, picture, picture.func, picture.args, picture.keywords
# Out:
# (<function __main__.tag(name, *content, cls=None, **attrs)>,
#  functools.partial(<function tag at 0x000002452802E680>, 'img', cls='pic-frame'),
#  <function __main__.tag(name, *content, cls=None, **attrs)>,
#  ('img',),
#  {'cls': 'pic-frame'})
